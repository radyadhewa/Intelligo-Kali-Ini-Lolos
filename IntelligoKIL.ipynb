# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dft_products = pd.read_csv('train/df_Products.csv')
dft_products
# Out:
#          product_id     product_category_name  product_weight_g  \
# 0      90K0C1fIyQUf                      toys             491.0
# 1      qejhpMGGVcsl             watches_gifts             440.0
# 2      qUS5d2pEAyxJ  costruction_tools_garden            2200.0
# 3      639iGvMyv0De                      toys            1450.0
# 4      1lycYGcsic2F                      toys             300.0
# ...             ...                       ...               ...
# 89311  W8vikEizUggJ                      toys             700.0
# 89312  KXSbyJWtMMwZ                      toys             600.0
# 89313  EG4wDSpFyTth             health_beauty             250.0
# 89314  ZWyg4uNWPHjJ                      toys             250.0
# 89315  5pbzE0rDy61l                      toys            1750.0
#
#        product_length_cm  product_height_cm  product_width_cm
# 0                   19.0               12.0              16.0
# 1                   18.0               14.0              17.0
# 2                   16.0               16.0              16.0
# 3                   68.0                3.0              48.0
# 4                   17.0                4.0              12.0
# ...                  ...                ...               ...
# 89311               21.0               14.0              14.0
# 89312               16.0               16.0              16.0
# 89313               22.0               10.0              18.0
# 89314               16.0                2.0              11.0
# 89315               32.0               18.0              24.0
#
# [89316 rows x 6 columns]

# %%
dft_payments = pd.read_csv('train/df_Payments.csv')
dft_payments
# Out:
#            order_id  payment_sequential payment_type  payment_installments  \
# 0      Axfy13Hk4PIk                   1  credit_card                     1
# 1      v6px92oS8cLG                   1  credit_card                     8
# 2      Ulpf9skrhjfm                   1  credit_card                     4
# 3      bwJVWupf2keN                   1  credit_card                     2
# 4      Dd0QnrMk9Cj5                   1  credit_card                     1
# ...             ...                 ...          ...                   ...
# 89311  zlcLnXGgAabl                   1       wallet                     1
# 89312  IlTAoIkILwrq                   1       wallet                     1
# 89313  uA6oXfftGVmT                   1  credit_card                     1
# 89314  v3QtU6xlGDJp                   1      voucher                     1
# 89315  Xo1fqyXOC6CR                   1  credit_card                    10
#
#        payment_value
# 0             259.14
# 1             382.39
# 2             249.25
# 3              27.79
# 4              76.15
# ...              ...
# 89311         128.00
# 89312         106.86
# 89313         376.39
# 89314          48.05
# 89315         211.93
#
# [89316 rows x 5 columns]

# %%
dft_orders = pd.read_csv('train/df_Orders.csv')
dft_orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2018-06-20 22:20:20       2018-07-03 22:51:22
# 2      2018-02-17 16:15:35       2018-02-27 01:29:50
# 3      2018-08-18 18:15:16       2018-08-27 20:03:51
# 4      2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                    ...                       ...
# 89311  2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312  2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313  2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314  2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315  2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 0                        2017-11-09
# 1                        2018-07-24
# 2                        2018-03-08
# 3                        2018-09-19
# 4                        2018-01-18
# ...                             ...
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05
#
# [89316 rows x 7 columns]

# %%
dft_orderitems = pd.read_csv('train/df_OrderItems.csv')
dft_orderitems
# Out:
#            order_id    product_id     seller_id    price  shipping_charges
# 0      Axfy13Hk4PIk  90K0C1fIyQUf  ZWM05J9LcBSF   223.51             84.65
# 1      v6px92oS8cLG  qejhpMGGVcsl  IjlpYfhUbRQs   170.80             23.79
# 2      Ulpf9skrhjfm  qUS5d2pEAyxJ  77p2EYxcM9MD    64.40             17.38
# 3      bwJVWupf2keN  639iGvMyv0De  jWzS0ayv9TGf   264.50             30.72
# 4      Dd0QnrMk9Cj5  1lycYGcsic2F  l1pYW6GBnPMr   779.90             30.66
# ...             ...           ...           ...      ...               ...
# 89311  zlcLnXGgAabl  W8vikEizUggJ  2QjevWskirjm    31.99            188.65
# 89312  IlTAoIkILwrq  KXSbyJWtMMwZ  BFS9XJPapWv0   282.00              1.64
# 89313  uA6oXfftGVmT  EG4wDSpFyTth  TuPm19CMKvrM    58.10              4.09
# 89314  v3QtU6xlGDJp  ZWyg4uNWPHjJ  yGbPyLPc8PmT  2899.00            113.01
# 89315  Xo1fqyXOC6CR  5pbzE0rDy61l  mkWN70fui2ro    37.88             70.06
#
# [89316 rows x 5 columns]

# %%
dft_customers = pd.read_csv('train/df_Customers.csv')
dft_customers
# Out:
#         customer_id  customer_zip_code_prefix       customer_city  \
# 0      hCT0x9JiGXBQ                     58125     varzea paulista
# 1      PxA7fv9spyhx                      3112  armacao dos buzios
# 2      g3nXeJkGI0Qw                      4119             jandira
# 3      EOEsCQ6QlpIg                     18212          uberlandia
# 4      mVz5LO2Vd6cL                     88868            ilhabela
# ...             ...                       ...                 ...
# 89311  bfJtzkBGksdY                     94060              amparo
# 89312  4hjsCpj6FC7g                     99835             itapevi
# 89313  DLn56oKHl9bv                      2540           sao paulo
# 89314  auSfRYUQUOIq                     12288            paulinia
# 89315  rhevVNXYJnEs                     93048            brasilia
#
#       customer_state
# 0                 SP
# 1                 RJ
# 2                 SP
# 3                 MG
# 4                 SP
# ...              ...
# 89311             SP
# 89312             SP
# 89313             SP
# 89314             SP
# 89315             DF
#
# [89316 rows x 4 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## DF Products EDA

# %%
dft_products.duplicated().sum()
# Out:
# 61865

# %%
duplicates = dft_products[dft_products.duplicated('product_id', keep=False)]
duplicate_counts = duplicates['product_id'].value_counts()

print("Duplicated values and their counts: \n")
print(duplicate_counts)
# Out:
# Duplicated values and their counts:
#
# 0vbEvli2JYJu    405
# UgkSjxoiV9Ev    383
# 9NwzO0Pm0fDM    383
# SLTlrWtcYt1m    321
# Biwi1BNtUB7l    295
#                ...
# N7kzArDjkVku      2
# lvWg0TQ5kWBT      2
# Awz9FAjPTQDE      2
# 1fYhNqhNEoln      2
# WPCsucIEHiJk      2
# Name: product_id, Length: 12796, dtype: int64

# %%
dft_products.isnull().sum()
# Out:
# product_id                 0
# product_category_name    308
# product_weight_g          15
# product_length_cm         15
# product_height_cm         15
# product_width_cm          15
# dtype: int64

# %%
mask_dft_null = dft_products[['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']].isna().any(axis=1)
dft_products[mask_dft_null]
# Out:
#          product_id product_category_name  product_weight_g  \
# 2150   zX9HL81jfvr2                  toys               NaN
# 7473   zX9HL81jfvr2                  toys               NaN
# 13628  VqyFCmRtRdfR                  toys               NaN
# 28114  zX9HL81jfvr2                  toys               NaN
# 32791  zX9HL81jfvr2                  toys               NaN
# 38130  zX9HL81jfvr2                  toys               NaN
# 39021  zX9HL81jfvr2                  toys               NaN
# 49124  zX9HL81jfvr2                  toys               NaN
# 55696  zX9HL81jfvr2                  toys               NaN
# 56195  zX9HL81jfvr2                  toys               NaN
# 57156  zX9HL81jfvr2                  toys               NaN
# 63531  zX9HL81jfvr2                  toys               NaN
# 68946  zX9HL81jfvr2                  toys               NaN
# 70321  zX9HL81jfvr2                  toys               NaN
# 88303  zX9HL81jfvr2                  toys               NaN
#
#        product_length_cm  product_height_cm  product_width_cm
# 2150                 NaN                NaN               NaN
# 7473                 NaN                NaN               NaN
# 13628                NaN                NaN               NaN
# 28114                NaN                NaN               NaN
# 32791                NaN                NaN               NaN
# 38130                NaN                NaN               NaN
# 39021                NaN                NaN               NaN
# 49124                NaN                NaN               NaN
# 55696                NaN                NaN               NaN
# 56195                NaN                NaN               NaN
# 57156                NaN                NaN               NaN
# 63531                NaN                NaN               NaN
# 68946                NaN                NaN               NaN
# 70321                NaN                NaN               NaN
# 88303                NaN                NaN               NaN

# %%
dft_products[dft_products['product_id'] == 'zX9HL81jfvr2']
# Out:
#          product_id product_category_name  product_weight_g  \
# 2150   zX9HL81jfvr2                  toys               NaN
# 7473   zX9HL81jfvr2                  toys               NaN
# 28114  zX9HL81jfvr2                  toys               NaN
# 32791  zX9HL81jfvr2                  toys               NaN
# 38130  zX9HL81jfvr2                  toys               NaN
# 39021  zX9HL81jfvr2                  toys               NaN
# 49124  zX9HL81jfvr2                  toys               NaN
# 55696  zX9HL81jfvr2                  toys               NaN
# 56195  zX9HL81jfvr2                  toys               NaN
# 57156  zX9HL81jfvr2                  toys               NaN
# 63531  zX9HL81jfvr2                  toys               NaN
# 68946  zX9HL81jfvr2                  toys               NaN
# 70321  zX9HL81jfvr2                  toys               NaN
# 88303  zX9HL81jfvr2                  toys               NaN
#
#        product_length_cm  product_height_cm  product_width_cm
# 2150                 NaN                NaN               NaN
# 7473                 NaN                NaN               NaN
# 28114                NaN                NaN               NaN
# 32791                NaN                NaN               NaN
# 38130                NaN                NaN               NaN
# 39021                NaN                NaN               NaN
# 49124                NaN                NaN               NaN
# 55696                NaN                NaN               NaN
# 56195                NaN                NaN               NaN
# 57156                NaN                NaN               NaN
# 63531                NaN                NaN               NaN
# 68946                NaN                NaN               NaN
# 70321                NaN                NaN               NaN
# 88303                NaN                NaN               NaN

# %%
dft_products[dft_products['product_id'] == 'VqyFCmRtRdfR']
# Out:
#          product_id product_category_name  product_weight_g  \
# 13628  VqyFCmRtRdfR                  toys               NaN
#
#        product_length_cm  product_height_cm  product_width_cm
# 13628                NaN                NaN               NaN

# %% [markdown]
# > Karena datanya 'Completely Missing at Random' maka kita bisa melakukan CCA atau drop null

# %%
null_dft = dft_products[['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']]

# %%
dft_products.dropna(axis=0, subset=null_dft.columns, inplace=True)

# %%
dft_products.isnull().sum() / len(dft_products)
# Out:
# product_id               0.000000
# product_category_name    0.003449
# product_weight_g         0.000000
# product_length_cm        0.000000
# product_height_cm        0.000000
# product_width_cm         0.000000
# dtype: float64

# %%
mask_dft_null = dft_products['product_category_name'].isna()
dft_products[mask_dft_null].head(10)
# Out:
#         product_id product_category_name  product_weight_g  product_length_cm  \
# 329   6cDVtksZH7KU                   NaN             200.0               16.0
# 1037  z6g5uM3fiCVO                   NaN             300.0               30.0
# 1179  N6XMQZiwCJ3t                   NaN             600.0               24.0
# 1589  W3IIy0dnIfkU                   NaN             200.0               16.0
# 3061  Z2X9RgoeYqaj                   NaN            6250.0               28.0
# 3210  CLZ9JZqycnNT                   NaN           10750.0               34.0
# 3632  x6gerAoELDdu                   NaN             500.0               24.0
# 3752  sNtRBW3JfRjj                   NaN             400.0               18.0
# 3825  OyECAoOQX8Ah                   NaN            2300.0               29.0
# 4444  PP5cKHUvzDD5                   NaN             600.0               35.0
#
#       product_height_cm  product_width_cm
# 329                 2.0              11.0
# 1037                6.0              12.0
# 1179                4.0              15.0
# 1589                2.0              11.0
# 3061               34.0              40.0
# 3210               20.0              30.0
# 3632                4.0              15.0
# 3752                7.0              17.0
# 3825               13.0              25.0
# 4444               35.0              15.0

# %%
dft_products[dft_products['product_id'] == 'PP5cKHUvzDD5']
# Out:
#          product_id product_category_name  product_weight_g  \
# 4444   PP5cKHUvzDD5                   NaN             600.0
# 14472  PP5cKHUvzDD5                   NaN             600.0
# 31035  PP5cKHUvzDD5                   NaN             600.0
# 82929  PP5cKHUvzDD5                   NaN             600.0
# 84377  PP5cKHUvzDD5                   NaN             600.0
#
#        product_length_cm  product_height_cm  product_width_cm
# 4444                35.0               35.0              15.0
# 14472               35.0               35.0              15.0
# 31035               35.0               35.0              15.0
# 82929               35.0               35.0              15.0
# 84377               35.0               35.0              15.0

# %% [markdown]
# > Karena ini juga CMAR dan hanya 0.0003% banyaknya yang kosong maka kita akan lakukan CCA saja

# %%
dft_products.dropna(inplace=True)
dft_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88993 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             88993 non-null  object
#  1   product_category_name  88993 non-null  object
#  2   product_weight_g       88993 non-null  float64
#  3   product_length_cm      88993 non-null  float64
#  4   product_height_cm      88993 non-null  float64
#  5   product_width_cm       88993 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 4.8+ MB

# %%
# Checking unique data
dft_products.nunique()
# Out:
# product_id               27308
# product_category_name       70
# product_weight_g          2019
# product_length_cm           99
# product_height_cm          101
# product_width_cm            93
# dtype: int64

# %%
dft_products['product_quantity'] = dft_products.groupby('product_id')['product_id'].transform('count')
dft_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88993 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             88993 non-null  object
#  1   product_category_name  88993 non-null  object
#  2   product_weight_g       88993 non-null  float64
#  3   product_length_cm      88993 non-null  float64
#  4   product_height_cm      88993 non-null  float64
#  5   product_width_cm       88993 non-null  float64
#  6   product_quantity       88993 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.4+ MB

# %%
dft_products = dft_products.drop_duplicates(subset='product_id')

# %%
dft_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27308 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             27308 non-null  object
#  1   product_category_name  27308 non-null  object
#  2   product_weight_g       27308 non-null  float64
#  3   product_length_cm      27308 non-null  float64
#  4   product_height_cm      27308 non-null  float64
#  5   product_width_cm       27308 non-null  float64
#  6   product_quantity       27308 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
sns.boxplot(data=dft_products,palette='cubehelix')
# Out:
# <AxesSubplot:>

# %%
dft_products.describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      27308.000000       27308.000000       27308.000000
# mean        2249.526695          30.725282          16.906035
# std         4218.946386          16.820427          13.632204
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1850.000000          38.000000          20.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm  product_quantity
# count      27308.000000      27308.000000
# mean          23.129632          3.258862
# std           12.009922          9.052738
# min            6.000000          1.000000
# 25%           15.000000          1.000000
# 50%           20.000000          1.000000
# 75%           30.000000          3.000000
# max          118.000000        405.000000

# %%
dft_products[dft_products['product_weight_g'] == 0]
# Out:
#          product_id product_category_name  product_weight_g  \
# 1476   fsq5lo34nHGK                  toys               0.0
# 51136  aMbBkxpim3xt                  toys               0.0
# 65518  nm5AMMVOx4Ac                  toys               0.0
# 83528  xUlGNJzxYn1N                  toys               0.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 1476                30.0               25.0              30.0
# 51136               30.0               25.0              30.0
# 65518               30.0               25.0              30.0
# 83528               30.0               25.0              30.0
#
#        product_quantity
# 1476                  2
# 51136                 2
# 65518                 1
# 83528                 1

# %% [markdown]
# ## DF Payments EDA

# %%
dft_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
dft_payments.duplicated().sum()
# Out:
# 0

# %%
dft_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              89316 non-null  object
#  1   payment_sequential    89316 non-null  int64
#  2   payment_type          89316 non-null  object
#  3   payment_installments  89316 non-null  int64
#  4   payment_value         89316 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.4+ MB

# %%
dft_payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count        89316.000000          89316.000000   89316.000000
# mean             1.099646              2.965717     268.657190
# std              0.772658              2.796406     344.409566
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      84.340000
# 50%              1.000000              2.000000     171.860000
# 75%              1.000000              4.000000     313.530000
# max             29.000000             24.000000    7274.880000

# %%
dft_payments[dft_payments['payment_installments'] == 5]
# Out:
#            order_id  payment_sequential payment_type  payment_installments  \
# 7      VEDSMTavbQwk                   1  credit_card                     5
# 160    BERp5cg4oEws                   1  credit_card                     5
# 165    dZuZBawSN57o                   1  credit_card                     5
# 173    TTBF9yOgN5EH                   1  credit_card                     5
# 195    MnaiNSJ6870y                   1  credit_card                     5
# ...             ...                 ...          ...                   ...
# 89204  CpcyAe7A6RCY                   1  credit_card                     5
# 89224  vm5VZGFFOqhQ                   1  credit_card                     5
# 89250  AYWBDUKtHx0m                   1  credit_card                     5
# 89263  0n06UN7fvlVZ                   1  credit_card                     5
# 89308  qFSh3lZILyQC                   1  credit_card                     5
#
#        payment_value
# 7             146.51
# 160           231.76
# 165           183.40
# 173           254.19
# 195            71.34
# ...              ...
# 89204         185.89
# 89224         386.76
# 89250         251.80
# 89263         255.69
# 89308         218.84
#
# [4600 rows x 5 columns]

# %%
dft_payments['payment_installments'].value_counts().sort_index()
# Out:
# 0         3
# 1     44313
# 2     10325
# 3      8907
# 4      6032
# 5      4600
# 6      3580
# 7      1401
# 8      3927
# 9       560
# 10     5331
# 11       18
# 12      128
# 13       17
# 14       11
# 15       73
# 16        6
# 17        6
# 18       26
# 20       16
# 21       10
# 22        1
# 23        1
# 24       24
# Name: payment_installments, dtype: int64

# %%
dft_payments[dft_payments['payment_value'] == 0]
# Out:
#            order_id  payment_sequential payment_type  payment_installments  \
# 65644  gZkNlHVVt1Xp                   1  credit_card                     8
#
#        payment_value
# 65644            0.0

# %%
dft_payments.drop(dft_payments[dft_payments['payment_value'] == 0].index, inplace=True)

# %%
dft_payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count        89315.000000          89315.000000   89315.000000
# mean             1.099647              2.965661     268.660198
# std              0.772663              2.796371     344.410321
# min              1.000000              0.000000       0.010000
# 25%              1.000000              1.000000      84.350000
# 50%              1.000000              2.000000     171.860000
# 75%              1.000000              4.000000     313.530000
# max             29.000000             24.000000    7274.880000

# %%
dft_payments_corr = dft_payments.corr()

plt.figure(figsize=(12,10))
sns.heatmap(dft_payments_corr, annot=True,annot_kws={'size':12},mask=np.triu(dft_payments_corr))

plt.show()

# %%
dft_payments['payment_type'].unique()
# Out:
# array(['credit_card', 'wallet', 'voucher', 'debit_card'], dtype=object)

# %%
plt.figure(figsize = (8,5))
ax = sns.countplot(data = dft_payments,x = "payment_type", palette ='cubehelix')
plt.title("Banyaknya jumlah pembayaran yang digunakan")
ax.set_xticklabels(ax.get_xticklabels(), ha='center', fontsize=8)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=8)


plt.show()

# %% [markdown]
# ## DF Orders EDA

# %%
dft_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   9
# order_delivered_timestamp        1889
# order_estimated_delivery_date       0
# dtype: int64

# %%
mask_deliv = dft_orders['order_delivered_timestamp'].isnull()

order_ndelivered = dft_orders[mask_deliv]

plt.figure(figsize = (8,5))
ax = sns.countplot(data = order_ndelivered,x = "order_status", palette ='cubehelix')
plt.title("Status dari pengiriman yang belum terdeliver")
ax.set_xticklabels(ax.get_xticklabels(), ha='center', fontsize=8)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=8)


plt.show()

# %%
dft_orders['order_status'].value_counts()
# Out:
# delivered      87428
# shipped          936
# canceled         409
# processing       273
# invoiced         266
# unavailable        2
# approved           2
# Name: order_status, dtype: int64

# %% [markdown]
# > kita ingin memprediksi karena ini sebenarnya banyak barang yang sudah shipped, jadi kenapa tanggal deliverednya gada. Kita mau masukkin rata2 lama sampai setelah approved di kota tersebut

# %%
dft_orders.head(3)
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
#
#      order_approved_at order_delivered_timestamp order_estimated_delivery_date
# 0  2017-10-22 19:14:13       2017-10-26 22:19:52                    2017-11-09
# 1  2018-06-20 22:20:20       2018-07-03 22:51:22                    2018-07-24
# 2  2018-02-17 16:15:35       2018-02-27 01:29:50                    2018-03-08

# %%
filtered_orders = dft_orders[(dft_orders['order_status'] == 'delivered') & (dft_orders['order_delivered_timestamp'].isnull())]
filtered_orders.head(10)
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 4254   t5kBjEdw3z8t  ZeIXZ7BBF5PP    delivered      2017-11-28 17:44:07
# 13268  BxxG20QRNt7K  RWhfv6bIMVsQ    delivered      2018-06-20 06:58:43
# 30892  yRSiD6TjWuMp  WrJg7MJuozgD    delivered      2018-07-01 22:05:55
# 65263  1XWJAxXBtYuW  Z5AHwQM14J3A    delivered      2018-06-08 12:09:39
# 65525  H6OIR9EVCoos  53rYCxN5t4tp    delivered      2018-06-27 16:09:12
# 67317  EznMwXRSIZcm  RMR2x4OEJS2K    delivered      2018-07-01 17:05:11
#
#          order_approved_at order_delivered_timestamp  \
# 4254   2017-11-28 17:56:40                       NaN
# 13268  2018-06-20 07:19:05                       NaN
# 30892  2018-07-01 22:15:14                       NaN
# 65263  2018-06-08 12:36:39                       NaN
# 65525  2018-06-27 16:29:30                       NaN
# 67317  2018-07-01 17:15:12                       NaN
#
#       order_estimated_delivery_date
# 4254                     2017-12-18
# 13268                    2018-07-16
# 30892                    2018-07-30
# 65263                    2018-06-26
# 65525                    2018-07-19
# 67317                    2018-07-30

# %%
filtered_orders2 = dft_orders[(dft_orders['order_status'] == 'delivered') & (dft_orders['order_approved_at'].isnull())]
filtered_orders2.head(10)
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 10788  4Itts2TBUQzs  Z3dI7uRBfJOD    delivered      2017-02-17 13:05:55
# 16137  6MPB830Ufh0n  SOtqXN1MqcLj    delivered      2017-02-17 17:21:55
# 28951  lqW95yj4n1Qd  jCPmhkcyVR1z    delivered      2017-02-18 15:52:27
# 30494  dn1i9D4DFVZ2  Es95IGZCDDXy    delivered      2017-02-17 15:53:27
# 41752  vBZCEuCG9Hf1  zHEH7vdeO6UZ    delivered      2017-02-18 11:04:19
# 42772  PXwPIjmXCehX  gjKhFw8AFnW1    delivered      2017-02-18 16:48:35
# 47768  Yg9HDkWtA3Q3  GFg4QWN26cLs    delivered      2017-02-19 01:28:47
# 59434  hynO4uEubWbe  QdQBjy8APVMg    delivered      2017-02-18 14:40:00
# 65247  Uso7EoEPMrLU  rKJOxQc2PTfc    delivered      2017-01-19 22:26:59
#
#       order_approved_at order_delivered_timestamp  \
# 10788               NaN       2017-03-02 11:09:19
# 16137               NaN       2017-03-03 12:16:03
# 28951               NaN       2017-03-07 13:57:47
# 30494               NaN       2017-03-03 11:47:47
# 41752               NaN       2017-03-02 16:15:23
# 42772               NaN       2017-03-09 07:28:47
# 47768               NaN       2017-03-02 03:41:58
# 59434               NaN       2017-03-01 13:25:33
# 65247               NaN       2017-02-06 14:22:19
#
#       order_estimated_delivery_date
# 10788                    2017-03-20
# 16137                    2017-03-20
# 28951                    2017-03-29
# 30494                    2017-03-23
# 41752                    2017-03-22
# 42772                    2017-03-31
# 47768                    2017-03-27
# 59434                    2017-03-17
# 65247                    2017-03-16

# %%
filtered_orders3 = dft_orders[(dft_orders['order_status'] == 'delivered') & (dft_orders['order_estimated_delivery_date'].isnull())]
filtered_orders3.head(10)
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_timestamp, order_estimated_delivery_date]
# Index: []

# %%
fill_mean_delivered = pd.merge(filtered_orders, dft_customers, on='customer_id')

# %%
fill_mean_delivered
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  t5kBjEdw3z8t  ZeIXZ7BBF5PP    delivered      2017-11-28 17:44:07
# 1  BxxG20QRNt7K  RWhfv6bIMVsQ    delivered      2018-06-20 06:58:43
# 2  yRSiD6TjWuMp  WrJg7MJuozgD    delivered      2018-07-01 22:05:55
# 3  1XWJAxXBtYuW  Z5AHwQM14J3A    delivered      2018-06-08 12:09:39
# 4  H6OIR9EVCoos  53rYCxN5t4tp    delivered      2018-06-27 16:09:12
# 5  EznMwXRSIZcm  RMR2x4OEJS2K    delivered      2018-07-01 17:05:11
#
#      order_approved_at order_delivered_timestamp  \
# 0  2017-11-28 17:56:40                       NaN
# 1  2018-06-20 07:19:05                       NaN
# 2  2018-07-01 22:15:14                       NaN
# 3  2018-06-08 12:36:39                       NaN
# 4  2018-06-27 16:29:30                       NaN
# 5  2018-07-01 17:15:12                       NaN
#
#   order_estimated_delivery_date  customer_zip_code_prefix    customer_city  \
# 0                    2017-12-18                      4931        cerquilho
# 1                    2018-07-16                     30270           quadra
# 2                    2018-07-30                      9432           sumare
# 3                    2018-06-26                      2349        guarulhos
# 4                    2018-07-19                     53423   ribeirao pires
# 5                    2018-07-30                     58423  pindamonhangaba
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             SP
# 4             SP
# 5             SP

# %%
df_4_mean = pd.merge(dft_orders, dft_customers, on='customer_id')
df_4_mean = df_4_mean[['customer_id', 'order_status', 'order_approved_at', 'order_delivered_timestamp', 'customer_zip_code_prefix']]
df_4_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89316 entries, 0 to 89315
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                89316 non-null  object
#  1   order_status               89316 non-null  object
#  2   order_approved_at          89307 non-null  object
#  3   order_delivered_timestamp  87427 non-null  object
#  4   customer_zip_code_prefix   89316 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.1+ MB

# %%
df_4_mean['customer_zip_code_prefix'].nunique()
# Out:
# 13930

# %%
df_4_mean['order_approved_at'] = pd.to_datetime(df_4_mean['order_approved_at'])
df_4_mean['order_delivered_timestamp'] = pd.to_datetime(df_4_mean['order_delivered_timestamp'])
df_4_mean['order_approved_at'] = df_4_mean['order_approved_at'].dt.strftime('%Y-%m-%d')
df_4_mean['order_delivered_timestamp'] = df_4_mean['order_delivered_timestamp'].dt.strftime('%Y-%m-%d')
df_4_mean.head()
# Out:
#     customer_id order_status order_approved_at order_delivered_timestamp  \
# 0  hCT0x9JiGXBQ    delivered        2017-10-22                2017-10-26
# 1  PxA7fv9spyhx    delivered        2018-06-20                2018-07-03
# 2  g3nXeJkGI0Qw    delivered        2018-02-17                2018-02-27
# 3  EOEsCQ6QlpIg    delivered        2018-08-18                2018-08-27
# 4  mVz5LO2Vd6cL    delivered        2017-12-22                2018-01-05
#
#    customer_zip_code_prefix
# 0                     58125
# 1                      3112
# 2                      4119
# 3                     18212
# 4                     88868

# %%
df_4_mean_fix = df_4_mean[df_4_mean['order_status'] == 'delivered']
df_4_mean_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87428 entries, 0 to 89315
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                87428 non-null  object
#  1   order_status               87428 non-null  object
#  2   order_approved_at          87419 non-null  object
#  3   order_delivered_timestamp  87422 non-null  object
#  4   customer_zip_code_prefix   87428 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ MB

# %%
df_4_mean_fix['order_delivered_timestamp'] = pd.to_datetime(df_4_mean_fix['order_delivered_timestamp'])
df_4_mean_fix['order_approved_at'] = pd.to_datetime(df_4_mean_fix['order_approved_at'])

df_4_mean_fix['Delivery Time'] = (df_4_mean_fix['order_delivered_timestamp'] - df_4_mean_fix['order_approved_at']).dt.days

df_4_mean_fix.head()
# Out:
# C:\Users\GF63\AppData\Local\Temp\ipykernel_9756\1259614140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4_mean_fix['order_delivered_timestamp'] = pd.to_datetime(df_4_mean_fix['order_delivered_timestamp'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_9756\1259614140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4_mean_fix['order_approved_at'] = pd.to_datetime(df_4_mean_fix['order_approved_at'])
# C:\Users\GF63\AppData\Local\Temp\ipykernel_9756\1259614140.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4_mean_fix['Delivery Time'] = (df_4_mean_fix['order_delivered_timestamp'] - df_4_mean_fix['order_approved_at']).dt.days
#     customer_id order_status order_approved_at order_delivered_timestamp  \
# 0  hCT0x9JiGXBQ    delivered        2017-10-22                2017-10-26
# 1  PxA7fv9spyhx    delivered        2018-06-20                2018-07-03
# 2  g3nXeJkGI0Qw    delivered        2018-02-17                2018-02-27
# 3  EOEsCQ6QlpIg    delivered        2018-08-18                2018-08-27
# 4  mVz5LO2Vd6cL    delivered        2017-12-22                2018-01-05
#
#    customer_zip_code_prefix  Delivery Time
# 0                     58125            4.0
# 1                      3112           13.0
# 2                      4119           10.0
# 3                     18212            9.0
# 4                     88868           14.0

# %%
mean_del_date = df_4_mean_fix.groupby('customer_zip_code_prefix').mean().reset_index()
mean_del_date.head()
# Out:
#    customer_zip_code_prefix  Delivery Time
# 0                      1003      17.333333
# 1                      1004      10.285714
# 2                      1005      14.333333
# 3                      1006      17.333333
# 4                      1007       9.500000

# %%
customer_ids_to_select = ['ZeIXZ7BBF5PP', 'RWhfv6bIMVsQ', 'WrJg7MJuozgD', 'Z5AHwQM14J3A', '53rYCxN5t4tp', 'RMR2x4OEJS2K']
df_4_mean[df_4_mean['customer_id'].isin(customer_ids_to_select)]
# Out:
#         customer_id order_status order_approved_at order_delivered_timestamp  \
# 4254   ZeIXZ7BBF5PP    delivered        2017-11-28                       NaN
# 13268  RWhfv6bIMVsQ    delivered        2018-06-20                       NaN
# 30892  WrJg7MJuozgD    delivered        2018-07-01                       NaN
# 65263  Z5AHwQM14J3A    delivered        2018-06-08                       NaN
# 65525  53rYCxN5t4tp    delivered        2018-06-27                       NaN
# 67317  RMR2x4OEJS2K    delivered        2018-07-01                       NaN
#
#        customer_zip_code_prefix
# 4254                       4931
# 13268                     30270
# 30892                      9432
# 65263                      2349
# 65525                     53423
# 67317                     58423

# %%
list_null_cust = [4931, 30270, 9432, 2349, 53423, 58423]

for i in list_null_cust:
    mean_time = mean_del_date[mean_del_date['customer_zip_code_prefix'] == i]['Delivery Time'].values[0]
    print(f'The mean time for delivery at {i} zipcode: {mean_time} days')
# Out:
# The mean time for delivery at 4931 zipcode: 10.848484848484848 days
# The mean time for delivery at 30270 zipcode: 9.0 days
# The mean time for delivery at 9432 zipcode: 9.0 days
# The mean time for delivery at 2349 zipcode: 4.0 days
# The mean time for delivery at 53423 zipcode: 5.0 days
# The mean time for delivery at 58423 zipcode: 6.0 days

# %%
df_4_mean = df_4_mean[df_4_mean['order_status'] == 'delivered'].reset_index()
null_delivered = df_4_mean['order_delivered_timestamp'].isnull()

df_4_mean[null_delivered]
# Out:
#        index   customer_id order_status order_approved_at  \
# 4163    4254  ZeIXZ7BBF5PP    delivered        2017-11-28
# 13001  13268  RWhfv6bIMVsQ    delivered        2018-06-20
# 30236  30892  WrJg7MJuozgD    delivered        2018-07-01
# 63904  65263  Z5AHwQM14J3A    delivered        2018-06-08
# 64159  65525  53rYCxN5t4tp    delivered        2018-06-27
# 65916  67317  RMR2x4OEJS2K    delivered        2018-07-01
#
#       order_delivered_timestamp  customer_zip_code_prefix
# 4163                        NaN                      4931
# 13001                       NaN                     30270
# 30236                       NaN                      9432
# 63904                       NaN                      2349
# 64159                       NaN                     53423
# 65916                       NaN                     58423

# %%
# Create a dictionary mapping zip codes to their mean delivery times
zip_mean_time_mapping = {
    4931: 10.848484848484848,
    30270: 9.0,
    9432: 9.0,
    2349: 4.0,
    53423: 5.0,
    58423: 6.0
}

# Fill missing values in 'Delivery Time' based on the mapping
for zip_code, mean_time in zip_mean_time_mapping.items():
    condition = (df_4_mean_fix['customer_zip_code_prefix'] == zip_code) & df_4_mean_fix['Delivery Time'].isna()
    df_4_mean_fix.loc[condition, 'Delivery Time'] = mean_time

# Display the updated DataFrame
df_4_mean_fix
# Out:
#         customer_id order_status order_approved_at order_delivered_timestamp  \
# 0      hCT0x9JiGXBQ    delivered        2017-10-22                2017-10-26
# 1      PxA7fv9spyhx    delivered        2018-06-20                2018-07-03
# 2      g3nXeJkGI0Qw    delivered        2018-02-17                2018-02-27
# 3      EOEsCQ6QlpIg    delivered        2018-08-18                2018-08-27
# 4      mVz5LO2Vd6cL    delivered        2017-12-22                2018-01-05
# ...             ...          ...               ...                       ...
# 89311  bfJtzkBGksdY    delivered        2018-08-21                2018-08-30
# 89312  4hjsCpj6FC7g    delivered        2017-12-16                2017-12-20
# 89313  DLn56oKHl9bv    delivered        2018-07-24                2018-07-27
# 89314  auSfRYUQUOIq    delivered        2018-08-11                2018-08-14
# 89315  rhevVNXYJnEs    delivered        2018-06-09                2018-06-14
#
#        customer_zip_code_prefix  Delivery Time
# 0                         58125            4.0
# 1                          3112           13.0
# 2                          4119           10.0
# 3                         18212            9.0
# 4                         88868           14.0
# ...                         ...            ...
# 89311                     94060            9.0
# 89312                     99835            4.0
# 89313                      2540            3.0
# 89314                     12288            3.0
# 89315                     93048            5.0
#
# [87428 rows x 6 columns]

# %%
df_4_mean[df_4_mean['order_delivered_timestamp'].isnull()]
# Out:
#        index   customer_id order_status order_approved_at  \
# 4163    4254  ZeIXZ7BBF5PP    delivered        2017-11-28
# 13001  13268  RWhfv6bIMVsQ    delivered        2018-06-20
# 30236  30892  WrJg7MJuozgD    delivered        2018-07-01
# 63904  65263  Z5AHwQM14J3A    delivered        2018-06-08
# 64159  65525  53rYCxN5t4tp    delivered        2018-06-27
# 65916  67317  RMR2x4OEJS2K    delivered        2018-07-01
#
#       order_delivered_timestamp  customer_zip_code_prefix
# 4163                        NaN                      4931
# 13001                       NaN                     30270
# 30236                       NaN                      9432
# 63904                       NaN                      2349
# 64159                       NaN                     53423
# 65916                       NaN                     58423

# %%
df_4_mean_fix[df_4_mean_fix['order_delivered_timestamp'].isnull()]
# Out:
#         customer_id order_status order_approved_at order_delivered_timestamp  \
# 4254   ZeIXZ7BBF5PP    delivered        2017-11-28                       NaT
# 13268  RWhfv6bIMVsQ    delivered        2018-06-20                       NaT
# 30892  WrJg7MJuozgD    delivered        2018-07-01                       NaT
# 65263  Z5AHwQM14J3A    delivered        2018-06-08                       NaT
# 65525  53rYCxN5t4tp    delivered        2018-06-27                       NaT
# 67317  RMR2x4OEJS2K    delivered        2018-07-01                       NaT
#
#        customer_zip_code_prefix  Delivery Time
# 4254                       4931      10.848485
# 13268                     30270       9.000000
# 30892                      9432       9.000000
# 65263                      2349       4.000000
# 65525                     53423       5.000000
# 67317                     58423       6.000000

# %%
# Assuming df_4_mean_fix is your DataFrame
df_4_mean_fix['order_approved_at'] = pd.to_datetime(df_4_mean_fix['order_approved_at'])  # Convert to datetime

# Calculate 'order_delivered_timestamp' based on 'order_approved_at' + 'Delivery Time' in days
mask_null = df_4_mean_fix['order_delivered_timestamp'].isnull()
df_4_mean_fix.loc[mask_null, 'order_delivered_timestamp'] = df_4_mean_fix.loc[mask_null, 'order_approved_at'] + pd.to_timedelta(df_4_mean_fix.loc[mask_null, 'Delivery Time'], unit='D')

# Display the updated DataFrame
df_4_mean_fix[df_4_mean_fix['customer_id'] == "ZeIXZ7BBF5PP"]
# Out:
#        customer_id order_status order_approved_at  \
# 4254  ZeIXZ7BBF5PP    delivered        2017-11-28
#
#          order_delivered_timestamp  customer_zip_code_prefix  Delivery Time
# 4254 2017-12-08 20:21:49.090867200                      4931      10.848485

# %%
df_4_mean_fix['order_approved_at'] = pd.to_datetime(df_4_mean_fix['order_approved_at'])
df_4_mean_fix['order_delivered_timestamp'] = pd.to_datetime(df_4_mean_fix['order_delivered_timestamp'])
df_4_mean_fix['order_approved_at'] = df_4_mean_fix['order_approved_at'].dt.strftime('%Y-%m-%d')
df_4_mean_fix['order_delivered_timestamp'] = df_4_mean_fix['order_delivered_timestamp'].dt.strftime('%Y-%m-%d')

df_4_mean_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87428 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                87428 non-null  object
#  1   order_status               87428 non-null  object
#  2   order_approved_at          87419 non-null  object
#  3   order_delivered_timestamp  87428 non-null  object
#  4   customer_zip_code_prefix   87428 non-null  int64
#  5   Delivery Time              87419 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.7+ MB

# %%
maskcheck = df_4_mean_fix['order_delivered_timestamp'].isnull()

df_4_mean_fix[maskcheck]
# Out:
# Empty DataFrame
# Columns: [customer_id, order_status, order_approved_at, order_delivered_timestamp, customer_zip_code_prefix, Delivery Time]
# Index: []

# %%
df_4_mean_fix[df_4_mean_fix['customer_id'] == 'Z3dI7uRBfJOD']
# Out:
#         customer_id order_status order_approved_at order_delivered_timestamp  \
# 10788  Z3dI7uRBfJOD    delivered               NaN                2017-03-02
#
#        customer_zip_code_prefix  Delivery Time
# 10788                     60441            NaN

# %%
df_4_mean_fix['customer_id'].duplicated().sum()
# Out:
# 0

# %%
dft_orders2 = dft_orders.merge(df_4_mean_fix[['customer_id', 'order_delivered_timestamp']], on='customer_id')
dft_orders2.head()
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
#
#      order_approved_at order_delivered_timestamp_x  \
# 0  2017-10-22 19:14:13         2017-10-26 22:19:52
# 1  2018-06-20 22:20:20         2018-07-03 22:51:22
# 2  2018-02-17 16:15:35         2018-02-27 01:29:50
# 3  2018-08-18 18:15:16         2018-08-27 20:03:51
# 4  2017-12-22 17:31:31         2018-01-05 19:22:49
#
#   order_estimated_delivery_date order_delivered_timestamp_y
# 0                    2017-11-09                  2017-10-26
# 1                    2018-07-24                  2018-07-03
# 2                    2018-03-08                  2018-02-27
# 3                    2018-09-19                  2018-08-27
# 4                    2018-01-18                  2018-01-05

# %%
dft_orders2['order_delivered_timestamp'] = dft_orders2['order_delivered_timestamp_y']

# Drop the 'order_delivered_timestamp_y' column if no longer needed
dft_orders2.drop(columns=['order_delivered_timestamp_x', 'order_delivered_timestamp_y'], inplace=True)
dft_orders2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87428 entries, 0 to 87427
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       87428 non-null  object
#  1   customer_id                    87428 non-null  object
#  2   order_status                   87428 non-null  object
#  3   order_purchase_timestamp       87428 non-null  object
#  4   order_approved_at              87419 non-null  object
#  5   order_estimated_delivery_date  87428 non-null  object
#  6   order_delivered_timestamp      87428 non-null  object
# dtypes: object(7)
# memory usage: 5.3+ MB

# %%
dft_orders2['order_status'].value_counts()
# Out:
# delivered    87428
# Name: order_status, dtype: int64

# %%
dft_orders[dft_orders['order_status'] == 'shipped']
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 41     C21fWds5zL0W  iFsAJRrzVaTS      shipped      2017-02-04 12:58:55
# 86     vSug5AqRo9gE  oWBBqGwqpx4m      shipped      2017-05-07 10:22:58
# 135    gQPaVIZUm0jj  LFLEYmt3mGzI      shipped      2017-10-20 19:51:41
# 205    yWHy7JXGvc0Z  K344NrOcLCky      shipped      2018-01-18 04:37:44
# 262    p6iWM5qft7BH  XTOCrs09YhZc      shipped      2017-07-12 22:05:52
# ...             ...           ...          ...                      ...
# 88802  Z2BLWRoHDxvh  939MDiVwtyHN      shipped      2017-04-16 06:31:08
# 89168  snTt1oxhyabE  CL6j3U6SCt17      shipped      2018-04-17 09:11:11
# 89196  VP3EBMExdh7K  acB2XNtto2SX      shipped      2018-01-24 18:19:18
# 89234  QzxMjvdMpOEI  yCbzy1m4tTUA      shipped      2017-09-15 09:05:41
# 89281  YCJoeAvBWkpq  BaZgf4zWhXSS      shipped      2018-03-06 11:13:39
#
#          order_approved_at order_delivered_timestamp  \
# 41     2017-02-04 13:10:38                       NaT
# 86     2017-05-09 09:35:20                       NaT
# 135    2017-10-20 20:05:36                       NaT
# 205    2018-01-18 04:52:09                       NaT
# 262    2017-07-14 02:25:32                       NaT
# ...                    ...                       ...
# 88802  2017-04-16 06:41:44                       NaT
# 89168  2018-04-17 09:31:33                       NaT
# 89196  2018-01-24 18:37:41                       NaT
# 89234  2017-09-15 09:15:13                       NaT
# 89281  2018-03-06 11:30:38                       NaT
#
#       order_estimated_delivery_date
# 41                       2017-03-15
# 86                       2017-06-12
# 135                      2017-11-13
# 205                      2018-02-22
# 262                      2017-08-01
# ...                             ...
# 88802                    2017-05-11
# 89168                    2018-05-24
# 89196                    2018-03-01
# 89234                    2017-10-05
# 89281                    2018-03-16
#
# [936 rows x 7 columns]

# %%
dft_orders['order_delivered_timestamp'] = pd.to_datetime(dft_orders['order_delivered_timestamp'])
max_date = dft_orders['order_delivered_timestamp'].max()
last_day_orders = dft_orders[dft_orders['order_delivered_timestamp'] == max_date]

# %%
last_day_orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 67050  MUTiAkk8Ohjx  0dP1RSBypl8a    delivered      2018-06-02 18:37:14
#
#          order_approved_at order_delivered_timestamp  \
# 67050  2018-06-02 18:51:31       2018-10-17 13:22:46
#
#       order_estimated_delivery_date
# 67050                    2018-07-13

# %%
dft_orders['order_status'].value_counts()
# Out:
# delivered      87428
# shipped          936
# canceled         409
# processing       273
# invoiced         266
# unavailable        2
# approved           2
# Name: order_status, dtype: int64

# %%
dft_orders[dft_orders['order_status'] == 'shipped'].count()
# Out:
# order_id                         936
# customer_id                      936
# order_status                     936
# order_purchase_timestamp         936
# order_approved_at                936
# order_delivered_timestamp          0
# order_estimated_delivery_date    936
# dtype: int64

# %%
fill_date = '2018-10-17 13:22:46'

# Fill NaN values in the "order_delivered_timestamp" column for "order_status" == 'shipped'
dft_orders.loc[dft_orders['order_status'] == 'shipped', 'order_delivered_timestamp'] = fill_date

# Print the updated DataFrame
dft_orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2018-06-20 22:20:20       2018-07-03 22:51:22
# 2      2018-02-17 16:15:35       2018-02-27 01:29:50
# 3      2018-08-18 18:15:16       2018-08-27 20:03:51
# 4      2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                    ...                       ...
# 89311  2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312  2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313  2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314  2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315  2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 0                        2017-11-09
# 1                        2018-07-24
# 2                        2018-03-08
# 3                        2018-09-19
# 4                        2018-01-18
# ...                             ...
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05
#
# [89316 rows x 7 columns]

# %%
dft_orders = dft_orders[(dft_orders['order_status'] == 'delivered') | (dft_orders['order_status'] == 'shipped')]
dft_orders.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                9
# order_delivered_timestamp        6
# order_estimated_delivery_date    0
# dtype: int64

# %%
merged_df = dft_orders.merge(dft_orders2, on='customer_id', how='left', suffixes=('', '_2'))
dft_orders['order_delivered_timestamp'].fillna(merged_df['order_delivered_timestamp_2'], inplace=True)
dft_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88364 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       88364 non-null  object
#  1   customer_id                    88364 non-null  object
#  2   order_status                   88364 non-null  object
#  3   order_purchase_timestamp       88364 non-null  object
#  4   order_approved_at              88355 non-null  object
#  5   order_delivered_timestamp      88364 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  88364 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 5.4+ MB
# C:\Users\GF63\AppData\Local\Temp\ipykernel_9756\1568852271.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft_orders['order_delivered_timestamp'].fillna(merged_df['order_delivered_timestamp_2'], inplace=True)

# %%
dft_orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2018-06-20 22:20:20       2018-07-03 22:51:22
# 2      2018-02-17 16:15:35       2018-02-27 01:29:50
# 3      2018-08-18 18:15:16       2018-08-27 20:03:51
# 4      2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                    ...                       ...
# 89311  2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312  2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313  2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314  2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315  2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 0                        2017-11-09
# 1                        2018-07-24
# 2                        2018-03-08
# 3                        2018-09-19
# 4                        2018-01-18
# ...                             ...
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05
#
# [88364 rows x 7 columns]

# %%
dft_orders.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                9
# order_delivered_timestamp        0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ## DF Order Items EDA

# %%
dft_orderitems.isnull().sum()
# Out:
# order_id            0
# product_id          0
# seller_id           0
# price               0
# shipping_charges    0
# dtype: int64

# %%
dft_orderitems.describe()
# Out:
#               price  shipping_charges
# count  89316.000000      89316.000000
# mean     340.900543         44.283210
# std      557.459897         37.672491
# min        0.850000          0.000000
# 25%       59.650000         20.110000
# 50%      136.900000         35.055000
# 75%      399.200000         57.190000
# max     6735.000000        409.680000

# %%
sns.boxplot(data=dft_orderitems)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## DF Customers EDA

# %%
dft_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
dft_customers.nunique()
# Out:
# customer_id                 89316
# customer_zip_code_prefix    13930
# customer_city                3735
# customer_state                 27
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
dft_products.head(2)
# Out:
#      product_id product_category_name  product_weight_g  product_length_cm  \
# 0  90K0C1fIyQUf                  toys             491.0               19.0
# 1  qejhpMGGVcsl         watches_gifts             440.0               18.0
#
#    product_height_cm  product_width_cm  product_quantity
# 0               12.0              16.0                13
# 1               14.0              17.0                 3

# %%
# Feature Creation on dft products

dft_products['product_size_cm'] = dft_products['product_length_cm'] * dft_products['product_height_cm'] * dft_products['product_width_cm']
dft_products.head(3)
# Out:
# C:\Users\GF63\AppData\Local\Temp\ipykernel_9756\3097694210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft_products['product_size_cm'] = dft_products['product_length_cm'] * dft_products['product_height_cm'] * dft_products['product_width_cm']
#      product_id     product_category_name  product_weight_g  \
# 0  90K0C1fIyQUf                      toys             491.0
# 1  qejhpMGGVcsl             watches_gifts             440.0
# 2  qUS5d2pEAyxJ  costruction_tools_garden            2200.0
#
#    product_length_cm  product_height_cm  product_width_cm  product_quantity  \
# 0               19.0               12.0              16.0                13
# 1               18.0               14.0              17.0                 3
# 2               16.0               16.0              16.0                 5
#
#    product_size_cm
# 0           3648.0
# 1           4284.0
# 2           4096.0

# %%
dft_payments.head(2)
# Out:
#        order_id  payment_sequential payment_type  payment_installments  \
# 0  Axfy13Hk4PIk                   1  credit_card                     1
# 1  v6px92oS8cLG                   1  credit_card                     8
#
#    payment_value
# 0         259.14
# 1         382.39

# %%
dft_orders.head(2)
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
#
#      order_approved_at order_delivered_timestamp order_estimated_delivery_date
# 0  2017-10-22 19:14:13       2017-10-26 22:19:52                    2017-11-09
# 1  2018-06-20 22:20:20       2018-07-03 22:51:22                    2018-07-24

# %%
dft_orderitems.head(2)
# Out:
#        order_id    product_id     seller_id   price  shipping_charges
# 0  Axfy13Hk4PIk  90K0C1fIyQUf  ZWM05J9LcBSF  223.51             84.65
# 1  v6px92oS8cLG  qejhpMGGVcsl  IjlpYfhUbRQs  170.80             23.79

# %%
dft_customers.head(2)
# Out:
#     customer_id  customer_zip_code_prefix       customer_city customer_state
# 0  hCT0x9JiGXBQ                     58125     varzea paulista             SP
# 1  PxA7fv9spyhx                      3112  armacao dos buzios             RJ

# %% [markdown]
# ## Feature Selection

# %%
dft_products['product_id'].duplicated().count()
# Out:
# 27308

# %%
dft_products = dft_products.drop_duplicates(subset='product_id')
dft_products['product_id'].nunique()
# Out:
# 27308

# %%
dft_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27308 entries, 0 to 89315
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             27308 non-null  object
#  1   product_category_name  27308 non-null  object
#  2   product_weight_g       27308 non-null  float64
#  3   product_length_cm      27308 non-null  float64
#  4   product_height_cm      27308 non-null  float64
#  5   product_width_cm       27308 non-null  float64
#  6   product_quantity       27308 non-null  int64
#  7   product_size_cm        27308 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
# Merge dft_orderitems with dft_products on 'product_id'
merged_orderitems_products = dft_orderitems.merge(dft_products[['product_id', 'product_weight_g', 'product_size_cm']], on='product_id', how='left')

# Merge dft_orders with merged_orderitems_products on 'order_id'
merged_orders = merged_orderitems_products.merge(dft_orders[['order_id','customer_id', 'order_status', 'order_delivered_timestamp', 'order_estimated_delivery_date']], on='order_id', how='inner')

# Merge dft_customers with merged_orders on 'customer_id'
final_merged_data = merged_orders.merge(dft_customers[['customer_id', 'customer_zip_code_prefix']], on='customer_id', how='left')

final_merged_data.head(3)
# Out:
#        order_id    product_id     seller_id   price  shipping_charges  \
# 0  Axfy13Hk4PIk  90K0C1fIyQUf  ZWM05J9LcBSF  223.51             84.65
# 1  v6px92oS8cLG  qejhpMGGVcsl  IjlpYfhUbRQs  170.80             23.79
# 2  Ulpf9skrhjfm  qUS5d2pEAyxJ  77p2EYxcM9MD   64.40             17.38
#
#    product_weight_g  product_size_cm   customer_id order_status  \
# 0             491.0           3648.0  hCT0x9JiGXBQ    delivered
# 1             440.0           4284.0  PxA7fv9spyhx    delivered
# 2            2200.0           4096.0  g3nXeJkGI0Qw    delivered
#
#   order_delivered_timestamp order_estimated_delivery_date  \
# 0       2017-10-26 22:19:52                    2017-11-09
# 1       2018-07-03 22:51:22                    2018-07-24
# 2       2018-02-27 01:29:50                    2018-03-08
#
#    customer_zip_code_prefix
# 0                     58125
# 1                      3112
# 2                      4119

# %%
final_merged_data.drop(columns='price', inplace=True)

# %%
final_merged_data['order_id'].apply(len).mean()
# Out:
# 12.0

# %%
final_merged_data['product_id'].apply(len).mean()
# Out:
# 12.0

# %%
final_merged_data['seller_id'].apply(len).mean()
# Out:
# 12.0

# %%
final_merged_data['customer_id'].apply(len).mean()
# Out:
# 12.0

# %%
final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88364 entries, 0 to 88363
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       88364 non-null  object
#  1   product_id                     88364 non-null  object
#  2   seller_id                      88364 non-null  object
#  3   shipping_charges               88364 non-null  float64
#  4   product_weight_g               88049 non-null  float64
#  5   product_size_cm                88049 non-null  float64
#  6   customer_id                    88364 non-null  object
#  7   order_status                   88364 non-null  object
#  8   order_delivered_timestamp      88364 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  88364 non-null  object
#  10  customer_zip_code_prefix       88364 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 8.1+ MB

# %%
final_merged_data['order_delivered_timestamp'] = pd.to_datetime(final_merged_data['order_delivered_timestamp'])
final_merged_data['order_estimated_delivery_date'] = pd.to_datetime(final_merged_data['order_estimated_delivery_date'])
final_merged_data['is_late'] = final_merged_data.apply(lambda row: 1 if row['order_delivered_timestamp'] > row['order_estimated_delivery_date'] else 0, axis=1)

# %%
final_merged_data.isnull().sum()
# Out:
# order_id                           0
# product_id                         0
# seller_id                          0
# shipping_charges                   0
# product_weight_g                 315
# product_size_cm                  315
# customer_id                        0
# order_status                       0
# order_delivered_timestamp          0
# order_estimated_delivery_date      0
# customer_zip_code_prefix           0
# is_late                            0
# dtype: int64

# %%
final_merged_data.dropna(axis=0, inplace=True)

# %%
final_merged_data = final_merged_data[final_merged_data['order_status'] == 'delivered']

# %%
final_merged_data['is_late'].value_counts()
# Out:
# 0    80417
# 1     6707
# Name: is_late, dtype: int64

# %%
final_merged_data['is_late'].unique()


plt.figure(figsize = (8,5))
ax = sns.countplot(data = final_merged_data,x = "is_late", palette ='cubehelix')
plt.title("Seberapa perbandingan telat dan tidak")
ax.set_xticklabels(ax.get_xticklabels(), ha='center', fontsize=8)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=8)


plt.show()

# %%
from sklearn.utils import resample

# %%
# Resample the classes with a lower n_samples
n_samples = min(len(final_merged_data[final_merged_data['is_late'] == 0]), len(final_merged_data[final_merged_data['is_late'] == 1]))

df_intime = resample(final_merged_data[final_merged_data['is_late'] == 0], 
                   replace=True,    
                   n_samples=6500,    
                   random_state=42)

df_late = resample(final_merged_data[final_merged_data['is_late'] == 1], 
                   replace=True,    
                   n_samples=6500,    
                   random_state=42) 

# Combine
final_merged_data = pd.concat([df_intime, df_late])
final_merged_data['is_late'].value_counts()
# Out:
# 0    6500
# 1    6500
# Name: is_late, dtype: int64

# %%
final_merged_data.reset_index(inplace=True)

# %% [markdown]
# # Encoding Final Merged Data

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Modeling

# %%
final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   index                          13000 non-null  int64
#  1   order_id                       13000 non-null  object
#  2   product_id                     13000 non-null  object
#  3   seller_id                      13000 non-null  object
#  4   shipping_charges               13000 non-null  float64
#  5   product_weight_g               13000 non-null  float64
#  6   product_size_cm                13000 non-null  float64
#  7   customer_id                    13000 non-null  object
#  8   order_status                   13000 non-null  object
#  9   order_delivered_timestamp      13000 non-null  datetime64[ns]
#  10  order_estimated_delivery_date  13000 non-null  datetime64[ns]
#  11  customer_zip_code_prefix       13000 non-null  int64
#  12  is_late                        13000 non-null  int64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(5)
# memory usage: 1.3+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_merged_data[['shipping_charges', 'product_weight_g', 'product_size_cm', 'customer_zip_code_prefix']]
y = final_merged_data['is_late']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123, shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
LR = RandomForestClassifier(random_state=123)
LR.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=123)

# %%
# Model Prediction
y_pred_train = LR.predict(X_train)
y_pred_train
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
y_pred_test = LR.predict(X_test)
y_pred_test
# Out:
# array([0, 1, 1, ..., 1, 0, 0], dtype=int64)

# %%
# Model Prediction Probability
LR.predict_proba(X_test)
# Out:
# array([[0.65, 0.35],
#        [0.44, 0.56],
#        [0.  , 1.  ],
#        ...,
#        [0.22, 0.78],
#        [0.56, 0.44],
#        [0.68, 0.32]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix

# %%
# Model Evaluation function
def model_evaluation(model, pred, xtrain, ytrain, xtest, ytest):
    print('Accuracy : %.3f' % accuracy_score(ytest, pred))
    print('Precision : %.3f' % precision_score(ytest, pred))
    print('Recall : %.3f' % recall_score(ytest, pred))
    print('F-1Score : %.3f' % f1_score(ytest, pred))
    
    fpr, tpr, thresholds = roc_curve(ytest, pred, pos_label=1) 
    print('ROC AUC : %.3f' % auc(fpr, tpr))
    
    # Average precision score
    average_precision = average_precision_score(ytest, pred)
    print('AP : %.3f'% average_precision)

# %%
model_evaluation(LR, y_pred_test, X_train, y_pred_train, X_test, y_test)
# Out:
# Accuracy : 0.726
# Precision : 0.708
# Recall : 0.755
# F-1Score : 0.731
# ROC AUC : 0.727
# AP : 0.655

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72      1651
#            1       0.71      0.76      0.73      1599
#
#     accuracy                           0.73      3250
#    macro avg       0.73      0.73      0.73      3250
# weighted avg       0.73      0.73      0.73      3250

# %%
conf_mat = confusion_matrix(y_test, y_pred_test)

# %%
label = [0,1]
sns.heatmap(
    conf_mat, 
    xticklabels=label, 
    yticklabels=label, 
    fmt='d', 
    annot_kws={'size':12},
    annot = True,
    cmap = 'mako'
    )
plt.xlabel('\nActual Result', fontsize=15, color='turquoise')
plt.ylabel('Prediction\n', fontsize=15, color='turquoise')
plt.title('\nResult w/ LR Model\n',  fontsize=20, color='navy')
# Out:
# Text(0.5, 1.0, '\nResult w/ LR Model\n')

# %% [markdown]
# ## Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# defining parameter range
param_grid = {
    'n_estimators': [10, 100, 200],
    'random_state': [0, 42, 123]
}

grid_search = GridSearchCV(LR, param_grid, scoring='accuracy', verbose=3)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ...n_estimators=10, random_state=0;, score=0.707 total time=   0.0s
# [CV 2/5] END ...n_estimators=10, random_state=0;, score=0.692 total time=   0.0s
# [CV 3/5] END ...n_estimators=10, random_state=0;, score=0.694 total time=   0.0s
# [CV 4/5] END ...n_estimators=10, random_state=0;, score=0.710 total time=   0.0s
# [CV 5/5] END ...n_estimators=10, random_state=0;, score=0.687 total time=   0.0s
# [CV 1/5] END ..n_estimators=10, random_state=42;, score=0.678 total time=   0.0s
# [CV 2/5] END ..n_estimators=10, random_state=42;, score=0.683 total time=   0.0s
# [CV 3/5] END ..n_estimators=10, random_state=42;, score=0.709 total time=   0.0s
# [CV 4/5] END ..n_estimators=10, random_state=42;, score=0.700 total time=   0.0s
# [CV 5/5] END ..n_estimators=10, random_state=42;, score=0.687 total time=   0.0s
# [CV 1/5] END .n_estimators=10, random_state=123;, score=0.686 total time=   0.1s
# [CV 2/5] END .n_estimators=10, random_state=123;, score=0.694 total time=   0.0s
# [CV 3/5] END .n_estimators=10, random_state=123;, score=0.690 total time=   0.0s
# [CV 4/5] END .n_estimators=10, random_state=123;, score=0.704 total time=   0.1s
# [CV 5/5] END .n_estimators=10, random_state=123;, score=0.677 total time=   0.0s
# [CV 1/5] END ..n_estimators=100, random_state=0;, score=0.695 total time=   1.2s
# [CV 2/5] END ..n_estimators=100, random_state=0;, score=0.695 total time=   1.3s
# [CV 3/5] END ..n_estimators=100, random_state=0;, score=0.700 total time=   1.2s
# [CV 4/5] END ..n_estimators=100, random_state=0;, score=0.707 total time=   1.2s
# [CV 5/5] END ..n_estimators=100, random_state=0;, score=0.677 total time=   1.2s
# [CV 1/5] END .n_estimators=100, random_state=42;, score=0.693 total time=   1.3s
# [CV 2/5] END .n_estimators=100, random_state=42;, score=0.696 total time=   1.2s
# [CV 3/5] END .n_estimators=100, random_state=42;, score=0.703 total time=   1.2s
# [CV 4/5] END .n_estimators=100, random_state=42;, score=0.700 total time=   1.2s
# [CV 5/5] END .n_estimators=100, random_state=42;, score=0.684 total time=   1.2s
# [CV 1/5] END n_estimators=100, random_state=123;, score=0.693 total time=   1.3s
# [CV 2/5] END n_estimators=100, random_state=123;, score=0.694 total time=   1.2s
# [CV 3/5] END n_estimators=100, random_state=123;, score=0.706 total time=   1.2s
# [CV 4/5] END n_estimators=100, random_state=123;, score=0.684 total time=   1.3s
# [CV 5/5] END n_estimators=100, random_state=123;, score=0.686 total time=   1.3s
# [CV 1/5] END ..n_estimators=200, random_state=0;, score=0.694 total time=   2.7s
# [CV 2/5] END ..n_estimators=200, random_state=0;, score=0.699 total time=   2.7s
# [CV 3/5] END ..n_estimators=200, random_state=0;, score=0.694 total time=   2.6s
# [CV 4/5] END ..n_estimators=200, random_state=0;, score=0.702 total time=   2.6s
# [CV 5/5] END ..n_estimators=200, random_state=0;, score=0.673 total time=   2.5s
# [CV 1/5] END .n_estimators=200, random_state=42;, score=0.698 total time=   2.6s
# [CV 2/5] END .n_estimators=200, random_state=42;, score=0.696 total time=   2.6s
# [CV 3/5] END .n_estimators=200, random_state=42;, score=0.704 total time=   2.5s
# [CV 4/5] END .n_estimators=200, random_state=42;, score=0.702 total time=   2.6s
# [CV 5/5] END .n_estimators=200, random_state=42;, score=0.684 total time=   2.6s
# [CV 1/5] END n_estimators=200, random_state=123;, score=0.694 total time=   2.6s
# [CV 2/5] END n_estimators=200, random_state=123;, score=0.689 total time=   2.6s
# [CV 3/5] END n_estimators=200, random_state=123;, score=0.692 total time=   2.5s
# [CV 4/5] END n_estimators=200, random_state=123;, score=0.690 total time=   2.6s
# [CV 5/5] END n_estimators=200, random_state=123;, score=0.675 total time=   2.7s
# GridSearchCV(estimator=RandomForestClassifier(random_state=123),
#              param_grid={'n_estimators': [10, 100, 200],
#                          'random_state': [0, 42, 123]},
#              scoring='accuracy', verbose=3)

# %%
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best Parameters:", best_params)
print("\nBest Estimator:", best_estimator)
# Out:
# Best Parameters: {'n_estimators': 10, 'random_state': 0}
#
# Best Estimator: RandomForestClassifier(n_estimators=10, random_state=0)

# %% [markdown]
# ## Modelling After Tune

# %%
RFC = RandomForestClassifier(n_estimators=10, random_state=0)
RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
# Model Prediction
y_pred_train = LR.predict(X_train)
y_pred_train
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
y_pred_test = LR.predict(X_test)
y_pred_test
# Out:
# array([0, 1, 1, ..., 1, 0, 0], dtype=int64)

# %%
# Model Prediction Probability
LR.predict_proba(X_test)
# Out:
# array([[0.65, 0.35],
#        [0.44, 0.56],
#        [0.  , 1.  ],
#        ...,
#        [0.22, 0.78],
#        [0.56, 0.44],
#        [0.68, 0.32]])

# %%
model_evaluation(LR, y_pred_test, X_train, y_pred_train, X_test, y_test)
# Out:
# Accuracy : 0.726
# Precision : 0.708
# Recall : 0.755
# F-1Score : 0.731
# ROC AUC : 0.727
# AP : 0.655

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72      1651
#            1       0.71      0.76      0.73      1599
#
#     accuracy                           0.73      3250
#    macro avg       0.73      0.73      0.73      3250
# weighted avg       0.73      0.73      0.73      3250

# %%
conf_mat = confusion_matrix(y_test, y_pred_test)

# %%
label = [0,1]
sns.heatmap(
    conf_mat, 
    xticklabels=label, 
    yticklabels=label, 
    fmt='d', 
    annot_kws={'size':12},
    annot = True,
    cmap = 'mako'
    )
plt.xlabel('\nActual Result', fontsize=15, color='turquoise')
plt.ylabel('Prediction\n', fontsize=15, color='turquoise')
plt.title('\nResult w/ LR Model\n',  fontsize=20, color='navy')
# Out:
# Text(0.5, 1.0, '\nResult w/ LR Model\n')

# %% [markdown]
# # Predict

# %%
df_test = pd.read_csv('test_order_id.csv')
df_test.head()
# Out:
#        order_id
# 0  u6rPMRAYIGig
# 1  ohY8f4FEbX19
# 2  I28liQek73i2
# 3  bBG1T89mlY8W
# 4  CYxJJSQS8Lbo

# %%
dfs_customers = pd.read_csv('test/df_Customers.csv')
dfs_customers
# Out:
#         customer_id  customer_zip_code_prefix        customer_city  \
# 0      I74lXDOfoqsp                      6020              goiania
# 1      47TuLHF2s7X5                     23020               viamao
# 2      dQ0dqI8Qwlj8                     75094             campinas
# 3      iQCmWhNkIczb                     89284  santana de parnaiba
# 4      Dp2g6JH8tO5Z                     39810             aripuana
# ...             ...                       ...                  ...
# 38274  Dw3aCTFf4Q4G                     26160            guarulhos
# 38275  JmHJqJvpVcJs                     39628       rio de janeiro
# 38276  ro5DikwWCC3j                     89284  santana de parnaiba
# 38277  R25nE2rl77AU                     60867            sao paulo
# 38278  oOvkrmF7ZZbI                     37740              diadema
#
#       customer_state
# 0                 GO
# 1                 RS
# 2                 SP
# 3                 SP
# 4                 MT
# ...              ...
# 38274             SP
# 38275             RJ
# 38276             SP
# 38277             SP
# 38278             SP
#
# [38279 rows x 4 columns]

# %%
dfs_orderitems = pd.read_csv('test/df_OrderItems.csv')
dfs_orderitems
# Out:
#            order_id    product_id     seller_id    price  shipping_charges
# 0      u6rPMRAYIGig  1slxdgbgWFax  3jwvL6ihC45G    24.10             20.90
# 1      ohY8f4FEbX19  77PgsiElQLeB  GlLj704QXlDB    42.89             12.28
# 2      I28liQek73i2  QVlD26X1y7NI  V3iKL8r9W9NR    50.21             67.11
# 3      bBG1T89mlY8W  yWlFGkKYfrpa  RNBdBKsXebna    89.10             62.05
# 4      CYxJJSQS8Lbo  h6MCbrwh5kiC  5Ja2lH0N2OZt  2139.99              9.41
# ...             ...           ...           ...      ...               ...
# 38274  QKBW3XKevmfn  wr6barwyoaIE  XURInBuULfIO    99.25             37.66
# 38275  Tjiw9bj8HtLr  sPZVXBD9lf3e  wR4cqCClYDyY    86.32             40.98
# 38276  mCPofb7A1aTq  Th6SHMsyTOMH  Gp2lLacVPwug   104.45             30.24
# 38277  scVuqN10zbgb  PyjlDSHRGdSt  al4fWZ5NFQzG   223.87             74.75
# 38278  oLKXX8tqU6eQ  UZQyp4CdjAIi  dHUHvmn8Gewy   692.00             52.93
#
# [38279 rows x 5 columns]

# %%
dfs_orders = pd.read_csv('test/df_Orders.csv')
dfs_orders
# Out:
#            order_id   customer_id order_purchase_timestamp  \
# 0      u6rPMRAYIGig  I74lXDOfoqsp      2017-11-18 12:29:57
# 1      ohY8f4FEbX19  47TuLHF2s7X5      2018-06-02 17:13:12
# 2      I28liQek73i2  dQ0dqI8Qwlj8      2018-01-08 11:01:30
# 3      bBG1T89mlY8W  iQCmWhNkIczb      2017-03-10 10:24:46
# 4      CYxJJSQS8Lbo  Dp2g6JH8tO5Z      2017-12-02 10:04:07
# ...             ...           ...                      ...
# 38274  QKBW3XKevmfn  Dw3aCTFf4Q4G      2018-08-24 11:54:56
# 38275  Tjiw9bj8HtLr  JmHJqJvpVcJs      2017-03-25 20:39:11
# 38276  mCPofb7A1aTq  ro5DikwWCC3j      2018-08-16 13:39:30
# 38277  scVuqN10zbgb  R25nE2rl77AU      2018-06-27 13:17:05
# 38278  oLKXX8tqU6eQ  oOvkrmF7ZZbI      2017-09-08 09:22:24
#
#          order_approved_at
# 0      2017-11-18 12:46:08
# 1      2018-06-02 20:12:23
# 2      2018-01-09 07:24:03
# 3      2017-03-10 10:24:46
# 4      2017-12-05 04:13:30
# ...                    ...
# 38274  2018-08-24 12:05:22
# 38275  2017-03-25 20:50:17
# 38276  2018-08-17 03:31:06
# 38277  2018-06-28 08:50:58
# 38278  2017-09-08 09:35:20
#
# [38279 rows x 4 columns]

# %%
dfs_products = pd.read_csv('test/df_Products.csv')
dfs_products
# Out:
#          product_id product_category_name  product_weight_g  \
# 0      1slxdgbgWFax                  toys              50.0
# 1      77PgsiElQLeB           electronics             200.0
# 2      QVlD26X1y7NI       furniture_decor            1000.0
# 3      yWlFGkKYfrpa                  toys            8950.0
# 4      h6MCbrwh5kiC                  toys            2301.0
# ...             ...                   ...               ...
# 38274  wr6barwyoaIE                  toys             200.0
# 38275  sPZVXBD9lf3e                  toys            5150.0
# 38276  Th6SHMsyTOMH                  toys             430.0
# 38277  PyjlDSHRGdSt                  toys            1850.0
# 38278  UZQyp4CdjAIi                  toys             200.0
#
#        product_length_cm  product_height_cm  product_width_cm
# 0                   16.0                5.0              11.0
# 1                   21.0                7.0              14.0
# 2                  100.0                5.0              20.0
# 3                   40.0               30.0              40.0
# 4                   32.0               35.0              34.0
# ...                  ...                ...               ...
# 38274               16.0               28.0              11.0
# 38275               22.0                3.0              22.0
# 38276               21.0               11.0              17.0
# 38277               24.0               36.0              23.0
# 38278               16.0                9.0              11.0
#
# [38279 rows x 6 columns]

# %%
dfs_products.isnull().sum()
# Out:
# product_id                 0
# product_category_name    168
# product_weight_g          10
# product_length_cm         10
# product_height_cm         10
# product_width_cm          10
# dtype: int64

# %%
def check_n_weight():
    if dfs_products['product_weight_g'].skew() > -0.5 and dfs_products['product_weight_g'].skew() < 0.5:
        print('Weight Normal')
    else:
        print('Weight Not Normal')

def check_n_length():
    if dfs_products['product_length_cm'].skew() > -0.5 and dfs_products['product_length_cm'].skew() < 0.5:
        print('Length Normal')
    else:
        print('Length Not Normal')

# %%
check_n_length()
check_n_weight()
# Out:
# Length Not Normal
# Weight Not Normal

# %%
# Calculate the medians for the columns with missing values
median_weight = dfs_products['product_weight_g'].median()
median_length = dfs_products['product_length_cm'].median()
median_height = dfs_products['product_height_cm'].median()
median_width = dfs_products['product_width_cm'].median()

# Fill missing values with medians
dfs_products['product_weight_g'].fillna(median_weight, inplace=True)
dfs_products['product_length_cm'].fillna(median_length, inplace=True)
dfs_products['product_height_cm'].fillna(median_height, inplace=True)
dfs_products['product_width_cm'].fillna(median_width, inplace=True)

# Verify that missing values have been filled
dfs_products.isnull().sum()
# Out:
# product_id                 0
# product_category_name    168
# product_weight_g           0
# product_length_cm          0
# product_height_cm          0
# product_width_cm           0
# dtype: int64

# %%
dfs_products['product_size_cm'] = dfs_products['product_length_cm'] * dfs_products['product_height_cm'] * dfs_products['product_width_cm']
dfs_products.head(3)
# Out:
#      product_id product_category_name  product_weight_g  product_length_cm  \
# 0  1slxdgbgWFax                  toys              50.0               16.0
# 1  77PgsiElQLeB           electronics             200.0               21.0
# 2  QVlD26X1y7NI       furniture_decor            1000.0              100.0
#
#    product_height_cm  product_width_cm  product_size_cm
# 0                5.0              11.0            880.0
# 1                7.0              14.0           2058.0
# 2                5.0              20.0          10000.0

# %%
# Merge dfs_orderitems with dfs_products on 'product_id'
merged_predict = dfs_orderitems.merge(dfs_products[['product_id', 'product_weight_g', 'product_size_cm']], on='product_id', how='inner')

# Merge dfs_orders with merged_predict on 'order_id'
merged_test = merged_predict.merge(dfs_orders[['order_id','customer_id']], on='order_id', how='inner')

# Merge dfs_customers with merged_test on 'customer_id'
final_merged_predict = merged_test.merge(dfs_customers[['customer_id', 'customer_zip_code_prefix']], on='customer_id', how='inner')

final_merged_predict
# Out:
#             order_id    product_id     seller_id   price  shipping_charges  \
# 0       u6rPMRAYIGig  1slxdgbgWFax  3jwvL6ihC45G   24.10             20.90
# 1       u6rPMRAYIGig  1slxdgbgWFax  3jwvL6ihC45G   24.10             20.90
# 2       u6rPMRAYIGig  1slxdgbgWFax  3jwvL6ihC45G   24.10             20.90
# 3       W883pN454zIH  1slxdgbgWFax  3jwvL6ihC45G   24.10             34.33
# 4       W883pN454zIH  1slxdgbgWFax  3jwvL6ihC45G   24.10             34.33
# ...              ...           ...           ...     ...               ...
# 483178  C6RN6xwcBVTe  x9UUywsqT92P  bgjDgOSuQsll  299.99             40.61
# 483179  tkxVd3HFludF  xltST60MG76S  WG2pVERAEzeW  171.90             32.95
# 483180  DI3Jz2puVexJ  Siea5ovIiWWX  9fFFM6RBxCkT  264.50             38.63
# 483181  kmViZI3t6fUT  LgjNH8kpQyJg  VjbLhhR5I7ly   78.55             26.99
# 483182  80nggXHcaGkw  pS9vX8gX7RHo  l1pYW6GBnPMr   27.64             32.34
#
#         product_weight_g  product_size_cm   customer_id  \
# 0                   50.0            880.0  I74lXDOfoqsp
# 1                   50.0            880.0  I74lXDOfoqsp
# 2                   50.0            880.0  I74lXDOfoqsp
# 3                   50.0            880.0  e3ksInKCwOpH
# 4                   50.0            880.0  e3ksInKCwOpH
# ...                  ...              ...           ...
# 483178             375.0           3120.0  yWToFHb5Gmi3
# 483179             800.0          15040.0  7yKRFDkrX5YA
# 483180             900.0          27000.0  dfso2oEhmURl
# 483181             650.0           1760.0  nh2pmBHvyIzL
# 483182             275.0            864.0  6hNdadF2uRJn
#
#         customer_zip_code_prefix
# 0                           6020
# 1                           6020
# 2                           6020
# 3                          18602
# 4                          18602
# ...                          ...
# 483178                      3081
# 483179                     15806
# 483180                     78850
# 483181                     54150
# 483182                     64049
#
# [483183 rows x 9 columns]

# %%
final_merged_predict.drop_duplicates(subset='order_id', inplace=True)
final_merged_predict
# Out:
#             order_id    product_id     seller_id   price  shipping_charges  \
# 0       u6rPMRAYIGig  1slxdgbgWFax  3jwvL6ihC45G   24.10             20.90
# 3       W883pN454zIH  1slxdgbgWFax  3jwvL6ihC45G   24.10             34.33
# 6       S7zJd1ziBFGA  1slxdgbgWFax  3jwvL6ihC45G  153.75             34.33
# 9       ohY8f4FEbX19  77PgsiElQLeB  GlLj704QXlDB   42.89             12.28
# 11      hI8Q4fQlN2Pu  77PgsiElQLeB  GlLj704QXlDB   42.89              6.87
# ...              ...           ...           ...     ...               ...
# 483178  C6RN6xwcBVTe  x9UUywsqT92P  bgjDgOSuQsll  299.99             40.61
# 483179  tkxVd3HFludF  xltST60MG76S  WG2pVERAEzeW  171.90             32.95
# 483180  DI3Jz2puVexJ  Siea5ovIiWWX  9fFFM6RBxCkT  264.50             38.63
# 483181  kmViZI3t6fUT  LgjNH8kpQyJg  VjbLhhR5I7ly   78.55             26.99
# 483182  80nggXHcaGkw  pS9vX8gX7RHo  l1pYW6GBnPMr   27.64             32.34
#
#         product_weight_g  product_size_cm   customer_id  \
# 0                   50.0            880.0  I74lXDOfoqsp
# 3                   50.0            880.0  e3ksInKCwOpH
# 6                   50.0            880.0  f3X7sB3PMDQW
# 9                  200.0           2058.0  47TuLHF2s7X5
# 11                 200.0           2058.0  AMEUpUsNWG0z
# ...                  ...              ...           ...
# 483178             375.0           3120.0  yWToFHb5Gmi3
# 483179             800.0          15040.0  7yKRFDkrX5YA
# 483180             900.0          27000.0  dfso2oEhmURl
# 483181             650.0           1760.0  nh2pmBHvyIzL
# 483182             275.0            864.0  6hNdadF2uRJn
#
#         customer_zip_code_prefix
# 0                           6020
# 3                          18602
# 6                          21550
# 9                          23020
# 11                         40110
# ...                          ...
# 483178                      3081
# 483179                     15806
# 483180                     78850
# 483181                     54150
# 483182                     64049
#
# [38279 rows x 9 columns]

# %%
final_merged_predict.reset_index(inplace=True)

# %%
final_merged_predict = final_merged_predict[['shipping_charges', 'product_weight_g', 'product_size_cm', 'customer_zip_code_prefix']]

# %%
final_merged_predict.head(2)
# Out:
#    shipping_charges  product_weight_g  product_size_cm  \
# 0             20.90              50.0            880.0
# 1             34.33              50.0            880.0
#
#    customer_zip_code_prefix
# 0                      6020
# 1                     18602

# %%
final_merged_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38279 entries, 0 to 38278
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   shipping_charges          38279 non-null  float64
#  1   product_weight_g          38279 non-null  float64
#  2   product_size_cm           38279 non-null  float64
#  3   customer_zip_code_prefix  38279 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 1.2 MB

# %%
predictions = RFC.predict(final_merged_predict)

# %%
final_merged_predict["is_late"] = predictions
# Out:
# C:\Users\GF63\AppData\Local\Temp\ipykernel_9756\2561033059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_merged_predict["is_late"] = predictions

# %%
final_merged_predict.head()
# Out:
#    shipping_charges  product_weight_g  product_size_cm  \
# 0             20.90              50.0            880.0
# 1             34.33              50.0            880.0
# 2             34.33              50.0            880.0
# 3             12.28             200.0           2058.0
# 4              6.87             200.0           2058.0
#
#    customer_zip_code_prefix  is_late
# 0                      6020        0
# 1                     18602        1
# 2                     21550        1
# 3                     23020        0
# 4                     40110        0

# %%
final_merged_predict.insert(0, 'order_id', df_test['order_id'])

# %%
final_merged_predict.head()
# Out:
#        order_id  shipping_charges  product_weight_g  product_size_cm  \
# 0  u6rPMRAYIGig             20.90              50.0            880.0
# 1  ohY8f4FEbX19             34.33              50.0            880.0
# 2  I28liQek73i2             34.33              50.0            880.0
# 3  bBG1T89mlY8W             12.28             200.0           2058.0
# 4  CYxJJSQS8Lbo              6.87             200.0           2058.0
#
#    customer_zip_code_prefix  is_late
# 0                      6020        0
# 1                     18602        1
# 2                     21550        1
# 3                     23020        0
# 4                     40110        0

# %%
df_test
# Out:
#            order_id
# 0      u6rPMRAYIGig
# 1      ohY8f4FEbX19
# 2      I28liQek73i2
# 3      bBG1T89mlY8W
# 4      CYxJJSQS8Lbo
# ...             ...
# 38274  QKBW3XKevmfn
# 38275  Tjiw9bj8HtLr
# 38276  mCPofb7A1aTq
# 38277  scVuqN10zbgb
# 38278  oLKXX8tqU6eQ
#
# [38279 rows x 1 columns]

# %%
sample = pd.read_csv('sample_submission.csv')
sample
# Out:
#        order_id  is_late
# 0  OhbVrpoiVgRV        0
# 1  5IfLBcbfnoGM        1
# 2  bJmTPSIAoCLr        0
# 3  Z3aWZkSBvrjn        0
# 4  9Wvgfygw2wMq        1
# 5  ZcUDIh7yfJs1        1
# 6  ON43xKmTecQo        0
# 7  Xsf2o3gyrDO1        0
# 8  xkxwnQrS7RPe        0
# 9  MOkIUpkDyr7O        0

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  10 non-null     object
#  1   is_late   10 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 288.0+ bytes

# %%
final_predict = final_merged_predict[['order_id', 'is_late']]
final_predict
# Out:
#            order_id  is_late
# 0      u6rPMRAYIGig        0
# 1      ohY8f4FEbX19        1
# 2      I28liQek73i2        1
# 3      bBG1T89mlY8W        0
# 4      CYxJJSQS8Lbo        0
# ...             ...      ...
# 38274  QKBW3XKevmfn        1
# 38275  Tjiw9bj8HtLr        0
# 38276  mCPofb7A1aTq        1
# 38277  scVuqN10zbgb        0
# 38278  oLKXX8tqU6eQ        0
#
# [38279 rows x 2 columns]

# %%
final_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38279 entries, 0 to 38278
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  38279 non-null  object
#  1   is_late   38279 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 598.2+ KB

# %%
final_predict['is_late'].value_counts()
# Out:
# 0    27258
# 1    11021
# Name: is_late, dtype: int64

# %%
final_predict.to_csv("Intelligo - ans 2.csv", index=False)
